# %% [markdown]
# <a href="https://colab.research.google.com/github/sathishsivam/Tamil-Tholkaappiyam/blob/main/Tamil_letters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tamil_vovels=['\u0b85','\u0b86','\u0b87','\u0b88','\u0b89','\u0b8A','\u0b8E','\u0b8F','\u0b90','\u0b92','\u0b93','\u0b94','\u0b83']

# %% [markdown]
# **உயிர் எழுத்துக்கள்**
#
# அ, ஆ, இ, ஈ, உ, ஊ, எ, ஏ, ஐ, ஒ, ஓ, ஒள இவை அனைத்துமே **உயிர் எழுத்துக்கள்** ஆகும். ஆகவே உயிர் எழுத்துக்கள் மொத்தமாக 12 உள்ளது.

# %%
for i in tamil_vovels:
  print(i)
# Out:
# அ
# ஆ
# இ
# ஈ
# உ
# ஊ
# எ
# ஏ
# ஐ
# ஒ
# ஓ
# ஔ
# ஃ

# %% [markdown]
# **மெய்யெழுத்துகள்**

# %%
tamil_consonants=["\u0b95","\u0b99","\u0b9A","\u0b9E","\u0b9F","\u0bA3","\u0ba4","\u0ba8","\u0baa","\u0bae","\u0baf","\u0bb0","\u0bb2","\u0bb5","\u0bb4","\u0bb3","\u0bb1","\u0ba9"]

# %%
for i in tamil_consonants:
  print(i)
# Out:
# க
# ங
# ச
# ஞ
# ட
# ண
# த
# ந
# ப
# ம
# ய
# ர
# ல
# வ
# ழ
# ள
# ற
# ன

# %%
dot="\u0bcd"

# %% [markdown]
# **மெய்யெழுத்துகள்** பிற இந்திய மொழி எழுத்துமுறைகளைப் போலவே தமிழிலும் அகரமேறிய மெய்களே அடிப்படைக் குறியீடுகளாக இருக்கின்றன. இவற்றுக்கு மேலே புள்ளி இடுவதன் மூலம் மெய்யொலிகள் குறிக்கப்படுகின்றன. மெய்யின் இயற்கை புள்ளியொடு நிலையல் என்று தொல்காப்பியம் குறிப்பிடுவதில் இருந்து இது பழமையான வழக்கு என்பதை அறிந்துகொள்ள முடியும்

# %%
tamil_consonant=[]

# %%
for i in tamil_consonants:
    tamil_consonant.append(i+dot)

# %%
tamil_consonant
# Out:
# ['க்',
#  'ங்',
#  'ச்',
#  'ஞ்',
#  'ட்',
#  'ண்',
#  'த்',
#  'ந்',
#  'ப்',
#  'ம்',
#  'ய்',
#  'ர்',
#  'ல்',
#  'வ்',
#  'ழ்',
#  'ள்',
#  'ற்',
#  'ன்']

# %%
tamil_ligature=["\u0bcd","\u0bbe","\u0bbf","\u0bc0","\u0bc1","\u0bc2","\u0bc6","\u0bc7","\u0bc8","\u0bca","\u0bcb","\u0bcc"]

# %%
list(i for i in tamil_ligature)
# Out:
# ['்', 'ா', 'ி', 'ீ', 'ு', 'ூ', 'ெ', 'ே', 'ை', 'ொ', 'ோ', 'ௌ']

# %%
for i in tamil_consonants:
            for j in tamil_ligature:
                print(i+j,end=" ")
            print("")
# Out:
# க் கா கி கீ கு கூ கெ கே கை கொ கோ கௌ
# ங் ஙா ஙி ஙீ ஙு ஙூ ஙெ ஙே ஙை ஙொ ஙோ ஙௌ
# ச் சா சி சீ சு சூ செ சே சை சொ சோ சௌ
# ஞ் ஞா ஞி ஞீ ஞு ஞூ ஞெ ஞே ஞை ஞொ ஞோ ஞௌ
# ட் டா டி டீ டு டூ டெ டே டை டொ டோ டௌ
# ண் ணா ணி ணீ ணு ணூ ணெ ணே ணை ணொ ணோ ணௌ
# த் தா தி தீ து தூ தெ தே தை தொ தோ தௌ
# ந் நா நி நீ நு நூ நெ நே நை நொ நோ நௌ
# ப் பா பி பீ பு பூ பெ பே பை பொ போ பௌ
# ம் மா மி மீ மு மூ மெ மே மை மொ மோ மௌ
# ய் யா யி யீ யு யூ யெ யே யை யொ யோ யௌ
# **ஆய்த எழுத்து** (ஃ) என்பது தமிழ் கற்றலுக்கான, முதன்மைக் குறியீடு ஆகும். இது ஃ என்றவாறு மூன்று புள்ளி வடிவமாக இருக்கும். இதற்கு அஃகேனம், தனிநிலை, முப்புள்ளி, முப்பாற்புள்ளி என்னும் வேறு பெயர்களும் உண்டு.[1]
#
# இவ்வெழுத்தானது தனக்கு முன்னர் ஒரு குறிலையும், பின்னர் ஒரு வல்லின உயிர்மெய் எழுத்தையும் பெற்றே வரும்.
#
# எடுத்துக்காட்டு
#
# அஃது - 'அ' குறில். 'து' வல்லின உயிர்மெய்
# இஃது - 'இ' குறில். 'து' வல்லின உயிர்மெய்

# %%
ஆய்த_எழுத்து='\u0b83'

# %%
ஆய்த_எழுத்து
# Out:
# 'ஃ'

# %%
class Tamil:
  def get_vovels(self):
    tamil_uyirmei=pd.DataFrame({"\u0b85":[i for i in tamil_consonants],
              "\u0b86":[i+"\u0bbe" for i in tamil_consonants],
              "\u0b87":[i+"\u0bbf" for i in tamil_consonants],
              "\u0b88":[i+"\u0bc0" for i in tamil_consonants],
              "\u0b89":[i+"\u0bc1" for i in tamil_consonants],
              "\u0b8A":[i+"\u0bc2" for i in tamil_consonants],
              "\u0b8E":[i+"\u0bc6" for i in tamil_consonants],
              "\u0b8F":[i+"\u0bc7" for i in tamil_consonants],
              "\u0b90":[i+"\u0bc8" for i in tamil_consonants],
              "\u0b92":[i+"\u0bca" for i in tamil_consonants],
              "\u0b93":[i+"\u0bcb" for i in tamil_consonants],
              "\u0b94":[i+"\u0bcc" for i in tamil_consonants]},index=tamil_consonant
            )
    return tamil_uyirmei

# %%
tam=Tamil()
tam.get_vovels()
# Out:
#     அ   ஆ   இ   ஈ   உ   ஊ   எ   ஏ   ஐ   ஒ   ஓ   ஔ
# க்  க  கா  கி  கீ  கு  கூ  கெ  கே  கை  கொ  கோ  கௌ
# ங்  ங  ஙா  ஙி  ஙீ  ஙு  ஙூ  ஙெ  ஙே  ஙை  ஙொ  ஙோ  ஙௌ
# ச்  ச  சா  சி  சீ  சு  சூ  செ  சே  சை  சொ  சோ  சௌ
# ஞ்  ஞ  ஞா  ஞி  ஞீ  ஞு  ஞூ  ஞெ  ஞே  ஞை  ஞொ  ஞோ  ஞௌ
# ட்  ட  டா  டி  டீ  டு  டூ  டெ  டே  டை  டொ  டோ  டௌ
# ண்  ண  ணா  ணி  ணீ  ணு  ணூ  ணெ  ணே  ணை  ணொ  ணோ  ணௌ
# த்  த  தா  தி  தீ  து  தூ  தெ  தே  தை  தொ  தோ  தௌ
# ந்  ந  நா  நி  நீ  நு  நூ  நெ  நே  நை  நொ  நோ  நௌ
# ப்  ப  பா  பி  பீ  பு  பூ  பெ  பே  பை  பொ  போ  பௌ
# ம்  ம  மா  மி  மீ  மு  மூ  மெ  மே  மை  மொ  மோ  மௌ
# ய்  ய  யா  யி  யீ  யு  யூ  யெ  யே  யை  யொ  யோ  யௌ
# ர்  ர  ரா  ரி  ரீ  ரு  ரூ  ரெ  ரே  ரை  ரொ  ரோ  ரௌ
# ல்  ல  லா  லி  லீ  லு  லூ  லெ  லே  லை  லொ  லோ  லௌ
# வ்  வ  வா  வி  வீ  வு  வூ  வெ  வே  வை  வொ  வோ  வௌ
# ழ்  ழ  ழா  ழி  ழீ  ழு  ழூ  ழெ  ழே  ழை  ழொ  ழோ  ழௌ
# ள்  ள  ளா  ளி  ளீ  ளு  ளூ  ளெ  ளே  ளை  ளொ  ளோ  ளௌ
# ற்  ற  றா  றி  றீ  று  றூ  றெ  றே  றை  றொ  றோ  றௌ
# ன்  ன  னா  னி  னீ  னு  னூ  னெ  னே  னை  னொ  னோ  னௌ
